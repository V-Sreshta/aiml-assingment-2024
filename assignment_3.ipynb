# %%
list=[1,2,3,4]

list1=[7,8,9,5]

print(list+list1)
# Out:
# [1, 2, 3, 4, 7, 8, 9, 5]

# %%
import numpy as np
list2=np.array(list)
list3=np.array(list1)

print(list2+list3)
# Out:
# [ 8 10 12  9]

# %%
print(list2**2)
# Out:
# [ 1  4  9 16]

# %%
s=[[1,2,3],[5,6,7,],[6,5,4]]
print(s)
# Out:
# [[1, 2, 3], [5, 6, 7], [6, 5, 4]]

# %%
print(s)
# Out:
# [[1, 2, 3], [5, 6, 7], [6, 5, 4]]

# %%
s1=np.array(s)
print(s1)
# Out:
# [[1 2 3]
#  [5 6 7]
#  [6 5 4]]

# %%
print(s1.shape)
# Out:
# (3, 3)

# %%
print(np.diagonal(s1))
# Out:
# [1 6 4]

# %%
print(np.mean(s1))
# Out:
# 4.333333333333333

# %%
print(np.max(s1))
# Out:
# 7

# %%
print(np.median(s1))
# Out:
# 5.0

# %%
print(np.linalg.inv(s1))
# Out:
# [[ 2.25179981e+15 -1.43296352e+15  8.18836296e+14]
#  [-4.50359963e+15  2.86592704e+15 -1.63767259e+15]
#  [ 2.25179981e+15 -1.43296352e+15  8.18836296e+14]]

# %%
print(np.linalg.eig(s1))
# Out:
# (array([ 1.31974022e+01, -2.19740216e+00, -6.82760113e-16]), array([[ 0.26986619,  0.51112091,  0.40824829],
#        [ 0.76111206,  0.3562053 , -0.81649658],
#        [ 0.5898141 , -0.78222324,  0.40824829]]))

# %%
print(np.linalg.det(s1))
# Out:
# -4.884981308350685e-15

# %%
x=d['latitude']
y=d['median_house_value']
plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b616fde93126> in <cell line: 1>()
# ----> 1 x=d['latitude']
#       2 y=d['median_house_value']
#       3 plt.plot(x,y)
#
# NameError: name 'd' is not defined

# %%
print(np.linalg.inv(s1))
# Out:
# [[ 2.25179981e+15 -1.43296352e+15  8.18836296e+14]
#  [-4.50359963e+15  2.86592704e+15 -1.63767259e+15]
#  [ 2.25179981e+15 -1.43296352e+15  8.18836296e+14]]

# %%
print(np.sin(30))
# Out:
# -0.9880316240928618

# %%
print(np.tanh(30))
# Out:
# 1.0

# %%
x=[1,2,3,4,5]
y=[4,5,6,7,8]
import matplotlib.pyplot as plt

# %%
plt.xlabel("this is x-axis")
plt.ylabel("this is y-axis")
plt.title("this is a title")
plt.hist(x,y)
# Out:
# (array([1., 1., 0., 0.]),
#  array([4., 5., 6., 7., 8.]),
#  <BarContainer object of 4 artists>)

# %%
import pandas as pd
d=pd.read_csv('/content/sample_data/california_housing_train.csv')
print(d)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %%
x=d['latitude']
y=d['median_house_value']
plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0c4d6147549f> in <cell line: 1>()
# ----> 1 x=d['latitude']
#       2 y=d['median_house_value']
#       3 plt.plot(x,y)
#       4
#       5
#
# NameError: name 'd' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
plt.pie(x)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-172f22aa615a> in <cell line: 3>()
#       1 from google.colab import drive
#       2 drive.mount('/content/drive')
# ----> 3 plt.pie(x)
#
# NameError: name 'plt' is not defined

# %%
x=d['latitude']
y=d['median_house_value']
plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b616fde93126> in <cell line: 1>()
# ----> 1 x=d['latitude']
#       2 y=d['median_house_value']
#       3 plt.plot(x,y)
#
# NameError: name 'd' is not defined

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
d=pd.read_csv('/content/sample_data/california_housing_train.csv')
print(d)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %%
x=d['latitude']
y=d['median_house_value']
plt.plot(x,y)

# %%
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x79d8a99153c0>,
#   <matplotlib.patches.Wedge at 0x79d8a9915c60>,
#   <matplotlib.patches.Wedge at 0x79d8a9917b50>,
#   <matplotlib.patches.Wedge at 0x79d8a9915cc0>,
#   <matplotlib.patches.Wedge at 0x79d8a9914370>,
#   <matplotlib.patches.Wedge at 0x79d8a99156f0>,
#   <matplotlib.patches.Wedge at 0x79d8a9916e30>,
#   <matplotlib.patches.Wedge at 0x79d8a99142e0>,
#   <matplotlib.patches.Wedge at 0x79d8a9915600>,
#   <matplotlib.patches.Wedge at 0x79d8a9914a60>,
#   <matplotlib.patches.Wedge at 0x79d8a99170d0>,
#   <matplotlib.patches.Wedge at 0x79d8a822c790>,
#   <matplotlib.patches.Wedge at 0x79d8a822caf0>,
#   <matplotlib.patches.Wedge at 0x79d8a822c2b0>,
#   <matplotlib.patches.Wedge at 0x79d8a822c7f0>,
#   <matplotlib.patches.Wedge at 0x79d8a822ed10>,
#   <matplotlib.patches.Wedge at 0x79d8a822f100>,
#   <matplotlib.patches.Wedge at 0x79d8a822d150>,
#   <matplotlib.patches.Wedge at 0x79d8a822d8d0>,
#   <matplotlib.patches.Wedge at 0x79d8a822cee0>,
#   <matplotlib.patches.Wedge at 0x79d8a822fd90>,
#   <matplotlib.patches.Wedge at 0x79d8a822d7b0>,
#   <matplotlib.patches.Wedge at 0x79d8a822fe80>,
#   <matplotlib.patches.Wedge at 0x79d8a822e4a0>,
#   <matplotlib.patches.Wedge at 0x79d8a822eb00>,
#   <matplotlib.patches.Wedge at 0x79d8a9837700>,
#   <matplotlib.patches.Wedge at 0x79d8a9837610>,
#   <matplotlib.patches.Wedge at 0x79d8a9837ee0>,
#   <matplotlib.patches.Wedge at 0x79d8a9836b00>,
#   <matplotlib.patches.Wedge at 0x79d8a98353f0>,
#   <matplotlib.patches.Wedge at 0x79d8a9834a00>,
#   <matplotlib.patches.Wedge at 0x79d8a9837e20>,
#   <matplotlib.patches.Wedge at 0x79d8a9835690>,
#   <matplotlib.patches.Wedge at 0x79d8a9836680>,
#   <matplotlib.patches.Wedge at 0x79d8a98367a0>,
#   <matplotlib.patches.Wedge at 0x79d8a98368f0>,
#   <matplotlib.patches.Wedge at 0x79d8a98362f0>,
#   <matplotlib.patches.Wedge at 0x79d8a98367d0>,
#   <matplotlib.patches.Wedge at 0x79d8a9834370>,
#   <matplotlib.patches.Wedge at 0x79d8a97758a0>,
#   <matplotlib.patches.Wedge at 0x79d8a97762f0>,
#   <matplotlib.patches.Wedge at 0x79d8a9775210>,
#   <matplotlib.patches.Wedge at 0x79d8a9774580>,
#   <matplotlib.patches.Wedge at 0x79d8a97751e0>,
#   <matplotlib.patches.Wedge at 0x79d8a9774a00>,
#   <matplotlib.patches.Wedge at 0x79d8a97756f0>,
#   <matplotlib.patches.Wedge at 0x79d8a97762c0>,
#   <matplotlib.patches.Wedge at 0x79d8a97778b0>,
#   <matplotlib.patches.Wedge at 0x79d8a9775c00>,
#   <matplotlib.patches.Wedge at 0x79d8a9774610>,
#   <matplotlib.patches.Wedge at 0x79d8a9774ca0>,
#   <matplotlib.patches.Wedge at 0x79d8a9774520>,
#   <matplotlib.patches.Wedge at 0x79d8a97754b0>,
#   <matplotlib.patches.Wedge at 0x79d8a81089a0>,
#   <matplotlib.patches.Wedge at 0x79d8a810ac20>,
#   <matplotlib.patches.Wedge at 0x79d8a81096c0>,
#   <matplotlib.patches.Wedge at 0x79d8a8108580>,
#   <matplotlib.patches.Wedge at 0x79d8a810ae30>,
#   <matplotlib.patches.Wedge at 0x79d8a8108e50>,
#   <matplotlib.patches.Wedge at 0x79d8a8109990>,
#   <matplotlib.patches.Wedge at 0x79d8a8109810>,
#   <matplotlib.patches.Wedge at 0x79d8a8108640>,
#   <matplotlib.patches.Wedge at 0x79d8a810a380>,
#   <matplotlib.patches.Wedge at 0x79d8a810bac0>,
#   <matplotlib.patches.Wedge at 0x79d8a810b670>,
#   <matplotlib.patches.Wedge at 0x79d8a81085b0>,
#   <matplotlib.patches.Wedge at 0x79d8a8108250>,
#   <matplotlib.patches.Wedge at 0x79d8a9799b70>,
#   <matplotlib.patches.Wedge at 0x79d8a979bdc0>,
#   <matplotlib.patches.Wedge at 0x79d8a9799480>,
#   <matplotlib.patches.Wedge at 0x79d8a9799900>,
#   <matplotlib.patches.Wedge at 0x79d8a979a110>,
#   <matplotlib.patches.Wedge at 0x79d8a979b460>,
#   <matplotlib.patches.Wedge at 0x79d8a979be20>,
#   <matplotlib.patches.Wedge at 0x79d8a9798130>,
#   <matplotlib.patches.Wedge at 0x79d8a979bc10>,
#   <matplotlib.patches.Wedge at 0x79d8a979bf70>,
#   <matplotlib.patches.Wedge at 0x79d8a9799930>,
#   <matplotlib.patches.Wedge at 0x79d8a9798490>,
#   <matplotlib.patches.Wedge at 0x79d8a979bac0>,
#   <matplotlib.patches.Wedge at 0x79d8a97983d0>,
#   <matplotlib.patches.Wedge at 0x79d8a813ac50>,
#   <matplotlib.patches.Wedge at 0x79d8a813aad0>,
#   <matplotlib.patches.Wedge at 0x79d8a8139990>,
#   <matplotlib.patches.Wedge at 0x79d8a813be50>,
#   <matplotlib.patches.Wedge at 0x79d8a813ab60>,
#   <matplotlib.patches.Wedge at 0x79d8a81398d0>,
#   <matplotlib.patches.Wedge at 0x79d8a813a050>,
#   <matplotlib.patches.Wedge at 0x79d8a8139030>,
#   <matplotlib.patches.Wedge at 0x79d8a813ad10>,
#   <matplotlib.patches.Wedge at 0x79d8a813b160>,
#   <matplotlib.patches.Wedge at 0x79d8a8139420>,
#   <matplotlib.patches.Wedge at 0x79d8a8139ae0>,
#   <matplotlib.patches.Wedge at 0x79d8a8139ea0>,
#   <matplotlib.patches.Wedge at 0x79d8a813a3b0>,
#   <matplotlib.patches.Wedge at 0x79d8ac1fe860>,
#   <matplotlib.patches.Wedge at 0x79d8ac1ff520>,
#   <matplotlib.patches.Wedge at 0x79d8ac1fd450>,
#   <matplotlib.patches.Wedge at 0x79d8ac1fcc40>,
#   <matplotlib.patches.Wedge at 0x79d8ac1fd810>,
#   <matplotlib.patches.Wedge at 0x79d8ac1ffa90>,
#   <matplotlib.patches.Wedge at 0x79d8ac1ff370>,
#   <matplotlib.patches.Wedge at 0x79d8ac1fcac0>,
#   <matplotlib.patches.Wedge at 0x79d8ac1fd6c0>,
#   <matplotlib.patches.Wedge at 0x79d8ac1fc340>,
#   <matplotlib.patches.Wedge at 0x79d8ac1ffc10>,
#   <matplotlib.patches.Wedge at 0x79d8ac1fc310>,
#   <matplotlib.patches.Wedge at 0x79d8ac1ffd30>,
#   <matplotlib.patches.Wedge at 0x79d8ac1ff1f0>,
#   <matplotlib.patches.Wedge at 0x79d8a983f430>,
#   <matplotlib.patches.Wedge at 0x79d8a983f490>,
#   <matplotlib.patches.Wedge at 0x79d8a983e350>,
#   <matplotlib.patches.Wedge at 0x79d8a983f5b0>,
#   <matplotlib.patches.Wedge at 0x79d8a983f4f0>,
#   <matplotlib.patches.Wedge at 0x79d8a983fcd0>,
#   <matplotlib.patches.Wedge at 0x79d8a983d4e0>,
#   <matplotlib.patches.Wedge at 0x79d8a983c820>,
#   <matplotlib.patches.Wedge at 0x79d8a983cb50>,
#   <matplotlib.patches.Wedge at 0x79d8a983f280>,
#   <matplotlib.patches.Wedge at 0x79d8a983ec50>,
#   <matplotlib.patches.Wedge at 0x79d8a983d3c0>,
#   <matplotlib.patches.Wedge at 0x79d8a983c9d0>,
#   <matplotlib.patches.Wedge at 0x79d8a9809c30>,
#   <matplotlib.patches.Wedge at 0x79d8a9809630>,
#   <matplotlib.patches.Wedge at 0x79d8a980a200>,
#   <matplotlib.patches.Wedge at 0x79d8a9808850>,
#   <matplotlib.patches.Wedge at 0x79d8a980b940>,
#   <matplotlib.patches.Wedge at 0x79d8a9808f10>,
#   <matplotlib.patches.Wedge at 0x79d8a9808a30>,
#   <matplotlib.patches.Wedge at 0x79d8a9809570>,
#   <matplotlib.patches.Wedge at 0x79d8a980a7d0>,
#   <matplotlib.patches.Wedge at 0x79d8a980a4d0>,
#   <matplotlib.patches.Wedge at 0x79d8a9808e80>,
#   <matplotlib.patches.Wedge at 0x79d8a9809330>,
#   <matplotlib.patches.Wedge at 0x79d8a980a9e0>,
#   <matplotlib.patches.Wedge at 0x79d8a9809450>,
#   <matplotlib.patches.Wedge at 0x79d8ac15da20>,
#   <matplotlib.patches.Wedge at 0x79d8a9885b70>,
#   <matplotlib.patches.Wedge at 0x79d8a98863b0>,
#   <matplotlib.patches.Wedge at 0x79d8a98873a0>,
#   <matplotlib.patches.Wedge at 0x79d8a9886140>,
#   <matplotlib.patches.Wedge at 0x79d8a9808a90>,
#   <matplotlib.patches.Wedge at 0x79d8a9884730>,
#   <matplotlib.patches.Wedge at 0x79d8a98843a0>,
#   <matplotlib.patches.Wedge at 0x79d8a9885c60>,
#   <matplotlib.patches.Wedge at 0x79d8a9885570>,
#   <matplotlib.patches.Wedge at 0x79d8a9884b20>,
#   <matplotlib.patches.Wedge at 0x79d8a9886d10>,
#   <matplotlib.patches.Wedge at 0x79d8a98871c0>,
#   <matplotlib.patches.Wedge at 0x79d8a9884640>,
#   <matplotlib.patches.Wedge at 0x79d8a9886f80>,
#   <matplotlib.patches.Wedge at 0x79d8a97d1db0>,
#   <matplotlib.patches.Wedge at 0x79d8a97d3730>,
#   <matplotlib.patches.Wedge at 0x79d8a97d2a40>,
#   <matplotlib.patches.Wedge at 0x79d8a97d3e80>,
#   <matplotlib.patches.Wedge at 0x79d8a97d0070>,
#   <matplotlib.patches.Wedge at 0x79d8a97d15d0>,
#   <matplotlib.patches.Wedge at 0x79d8a97d1ff0>,
#   <matplotlib.patches.Wedge at 0x79d8a97d1240>,
#   <matplotlib.patches.Wedge at 0x79d8a97d3a30>,
#   <matplotlib.patches.Wedge at 0x79d8a97d2800>,
#   <matplotlib.patches.Wedge at 0x79d8a97d1120>,
#   <matplotlib.patches.Wedge at 0x79d8a97d0fa0>,
#   <matplotlib.patches.Wedge at 0x79d8a97d2c80>,
#   <matplotlib.patches.Wedge at 0x79d8a97d1060>,
#   <matplotlib.patches.Wedge at 0x79d8a37285e0>,
#   <matplotlib.patches.Wedge at 0x79d8a3729000>,
#   <matplotlib.patches.Wedge at 0x79d8a372a560>,
#   <matplotlib.patches.Wedge at 0x79d8a372b310>,
#   <matplotlib.patches.Wedge at 0x79d8a372bac0>,
#   <matplotlib.patches.Wedge at 0x79d8a3728a60>,
#   <matplotlib.patches.Wedge at 0x79d8a37293f0>,
#   <matplotlib.patches.Wedge at 0x79d8a372ab60>,
#   <matplotlib.patches.Wedge at 0x79d8a372ad40>,
#   <matplotlib.patches.Wedge at 0x79d8a372a3e0>,
#   <matplotlib.patches.Wedge at 0x79d8a372a8c0>,
#   <matplotlib.patches.Wedge at 0x79d8a3728160>,
#   <matplotlib.patches.Wedge at 0x79d8a372b6a0>,
#   <matplotlib.patches.Wedge at 0x79d8a3729db0>,
#   <matplotlib.patches.Wedge at 0x79d8a372bbb0>,
#   <matplotlib.patches.Wedge at 0x79d8a98b8370>,
#   <matplotlib.patches.Wedge at 0x79d8a98bbd00>,
#   <matplotlib.patches.Wedge at 0x79d8a98b80a0>,
#   <matplotlib.patches.Wedge at 0x79d8a98ba170>,
#   <matplotlib.patches.Wedge at 0x79d8a98ba3e0>,
#   <matplotlib.patches.Wedge at 0x79d8a98ba9e0>,
#   <matplotlib.patches.Wedge at 0x79d8a98b9ba0>,
#   <matplotlib.patches.Wedge at 0x79d8a98ba080>,
#   <matplotlib.patches.Wedge at 0x79d8a98b8be0>,
#   <matplotlib.patches.Wedge at 0x79d8a98ba560>,
#   <matplotlib.patches.Wedge at 0x79d8a98bb6d0>,
#   <matplotlib.patches.Wedge at 0x79d8a98bae90>,
#   <matplotlib.patches.Wedge at 0x79d8a98b8340>,
#   <matplotlib.patches.Wedge at 0x79d8a98bb8e0>,
#   <matplotlib.patches.Wedge at 0x79d8a96643a0>,
#   <matplotlib.patches.Wedge at 0x79d8a9664820>,
#   <matplotlib.patches.Wedge at 0x79d8a9664ca0>,
#   <matplotlib.patches.Wedge at 0x79d8a9665120>,
#   <matplotlib.patches.Wedge at 0x79d8a96655a0>,
#   <matplotlib.patches.Wedge at 0x79d8a9665a20>,
#   <matplotlib.patches.Wedge at 0x79d8a9665ea0>,
#   <matplotlib.patches.Wedge at 0x79d8a9666320>,
#   <matplotlib.patches.Wedge at 0x79d8a9666770>,
#   <matplotlib.patches.Wedge at 0x79d8a9666c50>,
#   <matplotlib.patches.Wedge at 0x79d8a9667100>,
#   <matplotlib.patches.Wedge at 0x79d8a9667670>,
#   <matplotlib.patches.Wedge at 0x79d8a9667a30>,
#   <matplotlib.patches.Wedge at 0x79d8a9667eb0>,
#   <matplotlib.patches.Wedge at 0x79d8a8150370>,
#   <matplotlib.patches.Wedge at 0x79d8a81507f0>,
#   <matplotlib.patches.Wedge at 0x79d8a8150c70>,
#   <matplotlib.patches.Wedge at 0x79d8a81510f0>,
#   <matplotlib.patches.Wedge at 0x79d8a81515a0>,
#   <matplotlib.patches.Wedge at 0x79d8a8151a20>,
#   <matplotlib.patches.Wedge at 0x79d8a8151ea0>,
#   <matplotlib.patches.Wedge at 0x79d8a8152320>,
#   <matplotlib.patches.Wedge at 0x79d8a81527a0>,
#   <matplotlib.patches.Wedge at 0x79d8a8152c20>,
#   <matplotlib.patches.Wedge at 0x79d8a81530a0>,
#   <matplotlib.patches.Wedge at 0x79d8a8153520>,
#   <matplotlib.patches.Wedge at 0x79d8a81539a0>,
#   <matplotlib.patches.Wedge at 0x79d8a8153e20>,
#   <matplotlib.patches.Wedge at 0x79d8a80e02e0>,
#   <matplotlib.patches.Wedge at 0x79d8a80e0760>,
#   <matplotlib.patches.Wedge at 0x79d8a80e0be0>,
#   <matplotlib.patches.Wedge at 0x79d8a80e1060>,
#   <matplotlib.patches.Wedge at 0x79d8a80e14e0>,
#   <matplotlib.patches.Wedge at 0x79d8a80e1960>,
#   <matplotlib.patches.Wedge at 0x79d8a80e1de0>,
#   <matplotlib.patches.Wedge at 0x79d8a80e2260>,
#   <matplotlib.patches.Wedge at 0x79d8a80e26e0>,
#   <matplotlib.patches.Wedge at 0x79d8a80e2b60>,
#   <matplotlib.patches.Wedge at 0x79d8a80e2fe0>,
#   <matplotlib.patches.Wedge at 0x79d8a80e3460>,
#   <matplotlib.patches.Wedge at 0x79d8a80e38e0>,
#   <matplotlib.patches.Wedge at 0x79d8a80e3d60>,
#   <matplotlib.patches.Wedge at 0x79d8a3444220>,
#   <matplotlib.patches.Wedge at 0x79d8a34446a0>,
#   <matplotlib.patches.Wedge at 0x79d8a3444b20>,
#   <matplotlib.patches.Wedge at 0x79d8a3444fa0>,
#   <matplotlib.patches.Wedge at 0x79d8a3445420>,
#   <matplotlib.patches.Wedge at 0x79d8a34458a0>,
#   <matplotlib.patches.Wedge at 0x79d8a3445d20>,
#   <matplotlib.patches.Wedge at 0x79d8a34461a0>,
#   <matplotlib.patches.Wedge at 0x79d8a3446620>,
#   <matplotlib.patches.Wedge at 0x79d8a3446aa0>,
#   <matplotlib.patches.Wedge at 0x79d8a3446f20>,
#   <matplotlib.patches.Wedge at 0x79d8a34473a0>,
#   <matplotlib.patches.Wedge at 0x79d8a3447820>,
#   <matplotlib.patches.Wedge at 0x79d8a3447cd0>,
#   <matplotlib.patches.Wedge at 0x79d8a3438190>,
#   <matplotlib.patches.Wedge at 0x79d8a3438610>,
#   <matplotlib.patches.Wedge at 0x79d8a3438a90>,
#   <matplotlib.patches.Wedge at 0x79d8a3438f10>,
#   <matplotlib.patches.Wedge at 0x79d8a3439390>,
#   <matplotlib.patches.Wedge at 0x79d8a3439810>,
#   <matplotlib.patches.Wedge at 0x79d8a3439d20>,
#   <matplotlib.patches.Wedge at 0x79d8a343a1a0>,
#   <matplotlib.patches.Wedge at 0x79d8a343a620>,
#   <matplotlib.patches.Wedge at 0x79d8a343aaa0>,
#   <matplotlib.patches.Wedge at 0x79d8a343af20>,
#   <matplotlib.patches.Wedge at 0x79d8a343b3a0>,
#   <matplotlib.patches.Wedge at 0x79d8a343b820>,
#   <matplotlib.patches.Wedge at 0x79d8a343bca0>,
#   <matplotlib.patches.Wedge at 0x79d8a3480160>,
#   <matplotlib.patches.Wedge at 0x79d8a34805e0>,
#   <matplotlib.patches.Wedge at 0x79d8a3480a60>,
#   <matplotlib.patches.Wedge at 0x79d8a3480ee0>,
#   <matplotlib.patches.Wedge at 0x79d8a3481360>,
#   <matplotlib.patches.Wedge at 0x79d8a34817e0>,
#   <matplotlib.patches.Wedge at 0x79d8a3481c60>,
#   <matplotlib.patches.Wedge at 0x79d8a34820e0>,
#   <matplotlib.patches.Wedge at 0x79d8a3482560>,
#   <matplotlib.patches.Wedge at 0x79d8a34829e0>,
#   <matplotlib.patches.Wedge at 0x79d8a3482e60>,
#   <matplotlib.patches.Wedge at 0x79d8a34832e0>,
#   <matplotlib.patches.Wedge at 0x79d8a3483760>,
#   <matplotlib.patches.Wedge at 0x79d8a3483be0>,
#   <matplotlib.patches.Wedge at 0x79d8a34b40a0>,
#   <matplotlib.patches.Wedge at 0x79d8a34b4520>,
#   <matplotlib.patches.Wedge at 0x79d8a34b49a0>,
#   <matplotlib.patches.Wedge at 0x79d8a34b4e20>,
#   <matplotlib.patches.Wedge at 0x79d8a34b52a0>,
#   <matplotlib.patches.Wedge at 0x79d8a34b5720>,
#   <matplotlib.patches.Wedge at 0x79d8a34b5ba0>,
#   <matplotlib.patches.Wedge at 0x79d8a34b6020>,
#   <matplotlib.patches.Wedge at 0x79d8a34b64a0>,
#   <matplotlib.patches.Wedge at 0x79d8a34b6920>,
#   <matplotlib.patches.Wedge at 0x79d8a34b6da0>,
#   <matplotlib.patches.Wedge at 0x79d8a34b7220>,
#   <matplotlib.patches.Wedge at 0x79d8a34b76a0>,
#   <matplotlib.patches.Wedge at 0x79d8a34b7b20>,
#   <matplotlib.patches.Wedge at 0x79d8a34b7fa0>,
#   <matplotlib.patches.Wedge at 0x79d8a3314460>,
#   <matplotlib.patches.Wedge at 0x79d8a33148e0>,
#   <matplotlib.patches.Wedge at 0x79d8a3314d60>,
#   <matplotlib.patches.Wedge at 0x79d8a33151e0>,
#   <matplotlib.patches.Wedge at 0x79d8a3315660>,
#   <matplotlib.patches.Wedge at 0x79d8a3315ae0>,
#   <matplotlib.patches.Wedge at 0x79d8a3315f60>,
#   <matplotlib.patches.Wedge at 0x79d8a33163e0>,
#   <matplotlib.patches.Wedge at 0x79d8a3316860>,
#   <matplotlib.patches.Wedge at 0x79d8a3316ce0>,
#   <matplotlib.patches.Wedge at 0x79d8a3317160>,
#   <matplotlib.patches.Wedge at 0x79d8a33175e0>,
#   <matplotlib.patches.Wedge at 0x79d8a3317a90>,
#   <matplotlib.patches.Wedge at 0x79d8a3317f10>,
#   <matplotlib.patches.Wedge at 0x79d8a33583d0>,
#   <matplotlib.patches.Wedge at 0x79d8a3358850>,
#   <matplotlib.patches.Wedge at 0x79d8a3358cd0>,
#   <matplotlib.patches.Wedge at 0x79d8a3359150>,
#   <matplotlib.patches.Wedge at 0x79d8a33595d0>,
#   <matplotlib.patches.Wedge at 0x79d8a3359a50>,
#   <matplotlib.patches.Wedge at 0x79d8a3359ed0>,
#   <matplotlib.patches.Wedge at 0x79d8a335a350>,
#   <matplotlib.patches.Wedge at 0x79d8a335a7d0>,
#   <matplotlib.patches.Wedge at 0x79d8a335ac50>,
#   <matplotlib.patches.Wedge at 0x79d8a335b0d0>,
#   <matplotlib.patches.Wedge at 0x79d8a335b550>,
#   <matplotlib.patches.Wedge at 0x79d8a335b9d0>,
#   <matplotlib.patches.Wedge at 0x79d8a335be50>,
#   <matplotlib.patches.Wedge at 0x79d8a3394310>,
#   <matplotlib.patches.Wedge at 0x79d8a3394790>,
#   <matplotlib.patches.Wedge at 0x79d8a3394c10>,
#   <matplotlib.patches.Wedge at 0x79d8a3395090>,
#   <matplotlib.patches.Wedge at 0x79d8a3395510>,
#   <matplotlib.patches.Wedge at 0x79d8a3395990>,
#   <matplotlib.patches.Wedge at 0x79d8a3395e10>,
#   <matplotlib.patches.Wedge at 0x79d8a3396290>,
#   <matplotlib.patches.Wedge at 0x79d8a3396710>,
#   <matplotlib.patches.Wedge at 0x79d8a3396b90>,
#   <matplotlib.patches.Wedge at 0x79d8a3397010>,
#   <matplotlib.patches.Wedge at 0x79d8a3397490>,
#   <matplotlib.patches.Wedge at 0x79d8a3397910>,
#   <matplotlib.patches.Wedge at 0x79d8a3397d90>,
#   <matplotlib.patches.Wedge at 0x79d8a33cc250>,
#   <matplotlib.patches.Wedge at 0x79d8a33cc6d0>,
#   <matplotlib.patches.Wedge at 0x79d8a33ccb50>,
#   <matplotlib.patches.Wedge at 0x79d8a33ccfd0>,
#   <matplotlib.patches.Wedge at 0x79d8a33cd450>,
#   <matplotlib.patches.Wedge at 0x79d8a33cd8d0>,
#   <matplotlib.patches.Wedge at 0x79d8a33cdd50>,
#   <matplotlib.patches.Wedge at 0x79d8a33ce1d0>,
#   <matplotlib.patches.Wedge at 0x79d8a33ce650>,
#   <matplotlib.patches.Wedge at 0x79d8a33cead0>,
#   <matplotlib.patches.Wedge at 0x79d8a33cef50>,
#   <matplotlib.patches.Wedge at 0x79d8a33cf3d0>,
#   <matplotlib.patches.Wedge at 0x79d8a33cf850>,
#   <matplotlib.patches.Wedge at 0x79d8a33cfcd0>,
#   <matplotlib.patches.Wedge at 0x79d8a3204190>,
#   <matplotlib.patches.Wedge at 0x79d8a3204610>,
#   <matplotlib.patches.Wedge at 0x79d8a3204a90>,
#   <matplotlib.patches.Wedge at 0x79d8a3204f10>,
#   <matplotlib.patches.Wedge at 0x79d8a3205390>,
#   <matplotlib.patches.Wedge at 0x79d8a3205810>,
#   <matplotlib.patches.Wedge at 0x79d8a3205c90>,
#   <matplotlib.patches.Wedge at 0x79d8a3206110>,
#   <matplotlib.patches.Wedge at 0x79d8a3206590>,
#   <matplotlib.patches.Wedge at 0x79d8a3206a10>,
#   <matplotlib.patches.Wedge at 0x79d8a3206f80>,
#   <matplotlib.patches.Wedge at 0x79d8a3207340>,
#   <matplotlib.patches.Wedge at 0x79d8a32077c0>,
#   <matplotlib.patches.Wedge at 0x79d8a3207c40>,
#   <matplotlib.patches.Wedge at 0x79d8a3244100>,
#   <matplotlib.patches.Wedge at 0x79d8a3244580>,
#   <matplotlib.patches.Wedge at 0x79d8a3244a00>,
#   <matplotlib.patches.Wedge at 0x79d8a3244e80>,
#   <matplotlib.patches.Wedge at 0x79d8a3245300>,
#   <matplotlib.patches.Wedge at 0x79d8a3245780>,
#   <matplotlib.patches.Wedge at 0x79d8a3245c00>,
#   <matplotlib.patches.Wedge at 0x79d8a3246080>,
#   <matplotlib.patches.Wedge at 0x79d8a3246500>,
#   <matplotlib.patches.Wedge at 0x79d8a3246980>,
#   <matplotlib.patches.Wedge at 0x79d8a3246e00>,
#   <matplotlib.patches.Wedge at 0x79d8a3247280>,
#   <matplotlib.patches.Wedge at 0x79d8a3247700>,
#   <matplotlib.patches.Wedge at 0x79d8a3247b80>,
#   <matplotlib.patches.Wedge at 0x79d8a327c040>,
#   <matplotlib.patches.Wedge at 0x79d8a327c4c0>,
#   <matplotlib.patches.Wedge at 0x79d8a327c940>,
#   <matplotlib.patches.Wedge at 0x79d8a327cdc0>,
#   <matplotlib.patches.Wedge at 0x79d8a327d240>,
#   <matplotlib.patches.Wedge at 0x79d8a327d6c0>,
#   <matplotlib.patches.Wedge at 0x79d8a327db40>,
#   <matplotlib.patches.Wedge at 0x79d8a327dfc0>,
#   <matplotlib.patches.Wedge at 0x79d8a327e440>,
#   <matplotlib.patches.Wedge at 0x79d8a327e8c0>,
#   <matplotlib.patches.Wedge at 0x79d8a327ed40>,
#   <matplotlib.patches.Wedge at 0x79d8a327f1c0>,
#   <matplotlib.patches.Wedge at 0x79d8a327f640>,
#   <matplotlib.patches.Wedge at 0x79d8a327fac0>,
#   <matplotlib.patches.Wedge at 0x79d8a327ff40>,
#   <matplotlib.patches.Wedge at 0x79d8a32bc400>,
#   <matplotlib.patches.Wedge at 0x79d8a32bc880>,
#   <matplotlib.patches.Wedge at 0x79d8a32bcd00>,
#   <matplotlib.patches.Wedge at 0x79d8a32bd180>,
#   <matplotlib.patches.Wedge at 0x79d8a32bd600>,
#   <matplotlib.patches.Wedge at 0x79d8a32bda80>,
#   <matplotlib.patches.Wedge at 0x79d8a32bdf00>,
#   <matplotlib.patches.Wedge at 0x79d8a32be380>,
#   <matplotlib.patches.Wedge at 0x79d8a32be800>,
#   <matplotlib.patches.Wedge at 0x79d8a32bec80>,
#   <matplotlib.patches.Wedge at 0x79d8a32bf100>,
#   <matplotlib.patches.Wedge at 0x79d8a32bf580>,
#   <matplotlib.patches.Wedge at 0x79d8a32bfa00>,
#   <matplotlib.patches.Wedge at 0x79d8a32bfe80>,
#   <matplotlib.patches.Wedge at 0x79d8a32f8340>,
#   <matplotlib.patches.Wedge at 0x79d8a32f87c0>,
#   <matplotlib.patches.Wedge at 0x79d8a32f8c40>,
#   <matplotlib.patches.Wedge at 0x79d8a32f90c0>,
#   <matplotlib.patches.Wedge at 0x79d8a32f9540>,
#   <matplotlib.patches.Wedge at 0x79d8a32f99c0>,
#   <matplotlib.patches.Wedge at 0x79d8a32f9e40>,
#   <matplotlib.patches.Wedge at 0x79d8a32fa2c0>,
#   <matplotlib.patches.Wedge at 0x79d8a32fa740>,
#   <matplotlib.patches.Wedge at 0x79d8a32fabc0>,
#   <matplotlib.patches.Wedge at 0x79d8a32fb040>,
#   <matplotlib.patches.Wedge at 0x79d8a32fb4c0>,
#   <matplotlib.patches.Wedge at 0x79d8a32fb940>,
#   <matplotlib.patches.Wedge at 0x79d8a32fbdc0>,
#   <matplotlib.patches.Wedge at 0x79d8a3134280>,
#   <matplotlib.patches.Wedge at 0x79d8a3134700>,
#   <matplotlib.patches.Wedge at 0x79d8a3134b80>,
#   <matplotlib.patches.Wedge at 0x79d8a3135000>,
#   <matplotlib.patches.Wedge at 0x79d8a3135480>,
#   <matplotlib.patches.Wedge at 0x79d8a3135900>,
#   <matplotlib.patches.Wedge at 0x79d8a3135d80>,
#   <matplotlib.patches.Wedge at 0x79d8a3136230>,
#   <matplotlib.patches.Wedge at 0x79d8a31366b0>,
#   <matplotlib.patches.Wedge at 0x79d8a3136b30>,
#   <matplotlib.patches.Wedge at 0x79d8a3136fb0>,
#   <matplotlib.patches.Wedge at 0x79d8a3137430>,
#   <matplotlib.patches.Wedge at 0x79d8a31378b0>,
#   <matplotlib.patches.Wedge at 0x79d8a3137d30>,
#   <matplotlib.patches.Wedge at 0x79d8a316c1f0>,
#   <matplotlib.patches.Wedge at 0x79d8a316c670>,
#   <matplotlib.patches.Wedge at 0x79d8a316caf0>,
#   <matplotlib.patches.Wedge at 0x79d8a316cf70>,
#   <matplotlib.patches.Wedge at 0x79d8a316d3f0>,
#   <matplotlib.patches.Wedge at 0x79d8a316d870>,
#   <matplotlib.patches.Wedge at 0x79d8a316dcf0>,
#   <matplotlib.patches.Wedge at 0x79d8a316e170>,
#   <matplotlib.patches.Wedge at 0x79d8a316e5f0>,
#   <matplotlib.patches.Wedge at 0x79d8a316ea70>,
#   <matplotlib.patches.Wedge at 0x79d8a316eef0>,
#   <matplotlib.patches.Wedge at 0x79d8a316f370>,
#   <matplotlib.patches.Wedge at 0x79d8a316f7f0>,
#   <matplotlib.patches.Wedge at 0x79d8a316fc70>,
#   <matplotlib.patches.Wedge at 0x79d8a31a8130>,
#   <matplotlib.patches.Wedge at 0x79d8a31a85b0>,
#   <matplotlib.patches.Wedge at 0x79d8a31a8a30>,
#   <matplotlib.patches.Wedge at 0x79d8a31a8eb0>,
#   <matplotlib.patches.Wedge at 0x79d8a31a9330>,
#   <matplotlib.patches.Wedge at 0x79d8a31a97b0>,
#   <matplotlib.patches.Wedge at 0x79d8a31a9c30>,
#   <matplotlib.patches.Wedge at 0x79d8a31aa0b0>,
#   <matplotlib.patches.Wedge at 0x79d8a31aa530>,
#   <matplotlib.patches.Wedge at 0x79d8a31aa9b0>,
#   <matplotlib.patches.Wedge at 0x79d8a31aae30>,
#   <matplotlib.patches.Wedge at 0x79d8a31ab2b0>,
#   <matplotlib.patches.Wedge at 0x79d8a31ab730>,
#   <matplotlib.patches.Wedge at 0x79d8a31abbb0>,
#   <matplotlib.patches.Wedge at 0x79d8a31e4070>,
#   <matplotlib.patches.Wedge at 0x79d8a31e44f0>,
#   <matplotlib.patches.Wedge at 0x79d8a31e4970>,
#   <matplotlib.patches.Wedge at 0x79d8a31e4df0>,
#   <matplotlib.patches.Wedge at 0x79d8a31e5270>,
#   <matplotlib.patches.Wedge at 0x79d8a31e56f0>,
#   <matplotlib.patches.Wedge at 0x79d8a31e5b70>,
#   <matplotlib.patches.Wedge at 0x79d8a31e5ff0>,
#   <matplotlib.patches.Wedge at 0x79d8a31e6470>,
#   <matplotlib.patches.Wedge at 0x79d8a31e68f0>,
#   <matplotlib.patches.Wedge at 0x79d8a31e6d70>,
#   <matplotlib.patches.Wedge at 0x79d8a31e71f0>,
#   <matplotlib.patches.Wedge at 0x79d8a31e7670>,
#   <matplotlib.patches.Wedge at 0x79d8a31e7af0>,
#   <matplotlib.patches.Wedge at 0x79d8a31e7f70>,
#   <matplotlib.patches.Wedge at 0x79d8a3020430>,
#   <matplotlib.patches.Wedge at 0x79d8a30208b0>,
#   <matplotlib.patches.Wedge at 0x79d8a3020d30>,
#   <matplotlib.patches.Wedge at 0x79d8a30211b0>,
#   <matplotlib.patches.Wedge at 0x79d8a3021630>,
#   <matplotlib.patches.Wedge at 0x79d8a3021ab0>,
#   <matplotlib.patches.Wedge at 0x79d8a3021f30>,
#   <matplotlib.patches.Wedge at 0x79d8a30223b0>,
#   <matplotlib.patches.Wedge at 0x79d8a3022830>,
#   <matplotlib.patches.Wedge at 0x79d8a3022cb0>,
#   <matplotlib.patches.Wedge at 0x79d8a3023130>,
#   <matplotlib.patches.Wedge at 0x79d8a30235b0>,
#   <matplotlib.patches.Wedge at 0x79d8a3023a30>,
#   <matplotlib.patches.Wedge at 0x79d8a3023eb0>,
#   <matplotlib.patches.Wedge at 0x79d8a3058460>,
#   <matplotlib.patches.Wedge at 0x79d8a3058820>,
#   <matplotlib.patches.Wedge at 0x79d8a3058ca0>,
#   <matplotlib.patches.Wedge at 0x79d8a3059150>,
#   <matplotlib.patches.Wedge at 0x79d8a30595d0>,
#   <matplotlib.patches.Wedge at 0x79d8a3059a50>,
#   <matplotlib.patches.Wedge at 0x79d8a3059ed0>,
#   <matplotlib.patches.Wedge at 0x79d8a305a350>,
#   <matplotlib.patches.Wedge at 0x79d8a305a7d0>,
#   <matplotlib.patches.Wedge at 0x79d8a305ac50>,
#   <matplotlib.patches.Wedge at 0x79d8a305b0d0>,
#   <matplotlib.patches.Wedge at 0x79d8a305b550>,
#   <matplotlib.patches.Wedge at 0x79d8a305b9d0>,
#   <matplotlib.patches.Wedge at 0x79d8a305be50>,
#   <matplotlib.patches.Wedge at 0x79d8a309c310>,
#   <matplotlib.patches.Wedge at 0x79d8a309c790>,
#   <matplotlib.patches.Wedge at 0x79d8a309cc10>,
#   <matplotlib.patches.Wedge at 0x79d8a309d090>,
#   <matplotlib.patches.Wedge at 0x79d8a309d540>,
#   <matplotlib.patches.Wedge at 0x79d8a309d9c0>,
#   <matplotlib.patches.Wedge at 0x79d8a309de40>,
#   <matplotlib.patches.Wedge at 0x79d8a309e2c0>,
#   <matplotlib.patches.Wedge at 0x79d8a309e740>,
#   <matplotlib.patches.Wedge at 0x79d8a309ebc0>,
#   <matplotlib.patches.Wedge at 0x79d8a309f040>,
#   <matplotlib.patches.Wedge at 0x79d8a309f4c0>,
#   <matplotlib.patches.Wedge at 0x79d8a309f940>,
#   <matplotlib.patches.Wedge at 0x79d8a309fdc0>,
#   <matplotlib.patches.Wedge at 0x79d8a30cc280>,
#   <matplotlib.patches.Wedge at 0x79d8a30cc700>,
#   <matplotlib.patches.Wedge at 0x79d8a30ccb80>,
#   <matplotlib.patches.Wedge at 0x79d8a30cd000>,
#   <matplotlib.patches.Wedge at 0x79d8a30cd480>,
#   <matplotlib.patches.Wedge at 0x79d8a30cd900>,
#   <matplotlib.patches.Wedge at 0x79d8a30cdd80>,
#   <matplotlib.patches.Wedge at 0x79d8a30ce200>,
#   <matplotlib.patches.Wedge at 0x79d8a30ce680>,
#   <matplotlib.patches.Wedge at 0x79d8a30cecb0>,
#   <matplotlib.patches.Wedge at 0x79d8a30cf130>,
#   <matplotlib.patches.Wedge at 0x79d8a30cf580>,
#   <matplotlib.patches.Wedge at 0x79d8a30cf490>,
#   <matplotlib.patches.Wedge at 0x79d8a30cfd30>,
#   <matplotlib.patches.Wedge at 0x79d8a2f101f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f10670>,
#   <matplotlib.patches.Wedge at 0x79d8a2f10af0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f10f70>,
#   <matplotlib.patches.Wedge at 0x79d8a2f113f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f11870>,
#   <matplotlib.patches.Wedge at 0x79d8a2f11cf0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f12170>,
#   <matplotlib.patches.Wedge at 0x79d8a2f125f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f12a70>,
#   <matplotlib.patches.Wedge at 0x79d8a2f12ef0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f13370>,
#   <matplotlib.patches.Wedge at 0x79d8a2f137f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f13c70>,
#   <matplotlib.patches.Wedge at 0x79d8a2f4c130>,
#   <matplotlib.patches.Wedge at 0x79d8a2f4c5b0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f4ca30>,
#   <matplotlib.patches.Wedge at 0x79d8a2f4ceb0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f4d330>,
#   <matplotlib.patches.Wedge at 0x79d8a2f4d7b0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f4dc30>,
#   <matplotlib.patches.Wedge at 0x79d8a2f4e0b0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f4e530>,
#   <matplotlib.patches.Wedge at 0x79d8a2f4e9b0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f4ee30>,
#   <matplotlib.patches.Wedge at 0x79d8a2f4f2b0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f4f730>,
#   <matplotlib.patches.Wedge at 0x79d8a2f4fbb0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f88070>,
#   <matplotlib.patches.Wedge at 0x79d8a2f884f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f88970>,
#   <matplotlib.patches.Wedge at 0x79d8a2f88df0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f89270>,
#   <matplotlib.patches.Wedge at 0x79d8a2f896f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f89b70>,
#   <matplotlib.patches.Wedge at 0x79d8a2f89ff0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f8a470>,
#   <matplotlib.patches.Wedge at 0x79d8a2f8a8f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f8ad70>,
#   <matplotlib.patches.Wedge at 0x79d8a2f8b1f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f8b670>,
#   <matplotlib.patches.Wedge at 0x79d8a2f8baf0>,
#   <matplotlib.patches.Wedge at 0x79d8a2f8bf70>,
#   <matplotlib.patches.Wedge at 0x79d8a2fbc430>,
#   <matplotlib.patches.Wedge at 0x79d8a2fbc8b0>,
#   <matplotlib.patches.Wedge at 0x79d8a2fbcd30>,
#   <matplotlib.patches.Wedge at 0x79d8a2fbd1b0>,
#   <matplotlib.patches.Wedge at 0x79d8a2fbd630>,
#   <matplotlib.patches.Wedge at 0x79d8a2fbdab0>,
#   <matplotlib.patches.Wedge at 0x79d8a2fbdf30>,
#   <matplotlib.patches.Wedge at 0x79d8a2fbe3b0>,
#   <matplotlib.patches.Wedge at 0x79d8a2fbe830>,
#   <matplotlib.patches.Wedge at 0x79d8a2fbecb0>,
#   <matplotlib.patches.Wedge at 0x79d8a2fbf130>,
#   <matplotlib.patches.Wedge at 0x79d8a2fbf5b0>,
#   <matplotlib.patches.Wedge at 0x79d8a2fbfa30>,
#   <matplotlib.patches.Wedge at 0x79d8a2fbfeb0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e00370>,
#   <matplotlib.patches.Wedge at 0x79d8a2e007f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e00c70>,
#   <matplotlib.patches.Wedge at 0x79d8a2e010f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e01570>,
#   <matplotlib.patches.Wedge at 0x79d8a2e019f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e01e70>,
#   <matplotlib.patches.Wedge at 0x79d8a2e022f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e02770>,
#   <matplotlib.patches.Wedge at 0x79d8a2e02bf0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e03070>,
#   <matplotlib.patches.Wedge at 0x79d8a2e034f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e03970>,
#   <matplotlib.patches.Wedge at 0x79d8a2e03df0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e382b0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e38730>,
#   <matplotlib.patches.Wedge at 0x79d8a2e38bb0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e39030>,
#   <matplotlib.patches.Wedge at 0x79d8a2e394b0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e39930>,
#   <matplotlib.patches.Wedge at 0x79d8a2e39db0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e3a230>,
#   <matplotlib.patches.Wedge at 0x79d8a2e3a6b0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e3ab30>,
#   <matplotlib.patches.Wedge at 0x79d8a2e3afb0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e3b430>,
#   <matplotlib.patches.Wedge at 0x79d8a2e3b8b0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e3bd30>,
#   <matplotlib.patches.Wedge at 0x79d8a2e7c1f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e7c670>,
#   <matplotlib.patches.Wedge at 0x79d8a2e7caf0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e7cf70>,
#   <matplotlib.patches.Wedge at 0x79d8a2e7d3f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e7d870>,
#   <matplotlib.patches.Wedge at 0x79d8a2e7dcf0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e7e170>,
#   <matplotlib.patches.Wedge at 0x79d8a2e7e5f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e7ea70>,
#   <matplotlib.patches.Wedge at 0x79d8a2e7eef0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e7f370>,
#   <matplotlib.patches.Wedge at 0x79d8a2e7f7f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2e7fc70>,
#   <matplotlib.patches.Wedge at 0x79d8a2ea8130>,
#   <matplotlib.patches.Wedge at 0x79d8a2ea85b0>,
#   <matplotlib.patches.Wedge at 0x79d8a2ea8a30>,
#   <matplotlib.patches.Wedge at 0x79d8a2ea8eb0>,
#   <matplotlib.patches.Wedge at 0x79d8a2ea9330>,
#   <matplotlib.patches.Wedge at 0x79d8a2ea97b0>,
#   <matplotlib.patches.Wedge at 0x79d8a2ea9c30>,
#   <matplotlib.patches.Wedge at 0x79d8a2eaa0b0>,
#   <matplotlib.patches.Wedge at 0x79d8a2eaa530>,
#   <matplotlib.patches.Wedge at 0x79d8a2eaaaa0>,
#   <matplotlib.patches.Wedge at 0x79d8a2eaae60>,
#   <matplotlib.patches.Wedge at 0x79d8a2eab2e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2eab760>,
#   <matplotlib.patches.Wedge at 0x79d8a2eabbe0>,
#   <matplotlib.patches.Wedge at 0x79d8a2eec0a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2eec520>,
#   <matplotlib.patches.Wedge at 0x79d8a2eec9a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2eece20>,
#   <matplotlib.patches.Wedge at 0x79d8a2eed2a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2eed720>,
#   <matplotlib.patches.Wedge at 0x79d8a2eedba0>,
#   <matplotlib.patches.Wedge at 0x79d8a2eee020>,
#   <matplotlib.patches.Wedge at 0x79d8a2eee4a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2eee920>,
#   <matplotlib.patches.Wedge at 0x79d8a2eeeda0>,
#   <matplotlib.patches.Wedge at 0x79d8a2eef220>,
#   <matplotlib.patches.Wedge at 0x79d8a2eef6a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2eefb20>,
#   <matplotlib.patches.Wedge at 0x79d8a2eeffa0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d24460>,
#   <matplotlib.patches.Wedge at 0x79d8a2d248e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d24d60>,
#   <matplotlib.patches.Wedge at 0x79d8a2d251e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d25660>,
#   <matplotlib.patches.Wedge at 0x79d8a2d25ae0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d25f60>,
#   <matplotlib.patches.Wedge at 0x79d8a2d263e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d26860>,
#   <matplotlib.patches.Wedge at 0x79d8a2d26ce0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d27160>,
#   <matplotlib.patches.Wedge at 0x79d8a2d275e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d27a60>,
#   <matplotlib.patches.Wedge at 0x79d8a2d27ee0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d603a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d60820>,
#   <matplotlib.patches.Wedge at 0x79d8a2d60ca0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d61120>,
#   <matplotlib.patches.Wedge at 0x79d8a2d615a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d61a20>,
#   <matplotlib.patches.Wedge at 0x79d8a2d61ea0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d62320>,
#   <matplotlib.patches.Wedge at 0x79d8a2d627a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d62c20>,
#   <matplotlib.patches.Wedge at 0x79d8a2d630a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d63520>,
#   <matplotlib.patches.Wedge at 0x79d8a2d639a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d63e20>,
#   <matplotlib.patches.Wedge at 0x79d8a2d982e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d98760>,
#   <matplotlib.patches.Wedge at 0x79d8a2d98be0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d99060>,
#   <matplotlib.patches.Wedge at 0x79d8a2d994e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d99960>,
#   <matplotlib.patches.Wedge at 0x79d8a2d99de0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d9a260>,
#   <matplotlib.patches.Wedge at 0x79d8a2d9a6e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d9ab60>,
#   <matplotlib.patches.Wedge at 0x79d8a2d9afe0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d9b460>,
#   <matplotlib.patches.Wedge at 0x79d8a2d9b8e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2d9bd60>,
#   <matplotlib.patches.Wedge at 0x79d8a2dd0220>,
#   <matplotlib.patches.Wedge at 0x79d8a2dd06a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2dd0b20>,
#   <matplotlib.patches.Wedge at 0x79d8a2dd0fa0>,
#   <matplotlib.patches.Wedge at 0x79d8a2dd1420>,
#   <matplotlib.patches.Wedge at 0x79d8a2dd18a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2dd1d20>,
#   <matplotlib.patches.Wedge at 0x79d8a2dd21a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2dd2620>,
#   <matplotlib.patches.Wedge at 0x79d8a2dd2aa0>,
#   <matplotlib.patches.Wedge at 0x79d8a2dd2f20>,
#   <matplotlib.patches.Wedge at 0x79d8a2dd33a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2dd3820>,
#   <matplotlib.patches.Wedge at 0x79d8a2dd3ca0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c14160>,
#   <matplotlib.patches.Wedge at 0x79d8a2c145e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c14a60>,
#   <matplotlib.patches.Wedge at 0x79d8a2c14ee0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c15360>,
#   <matplotlib.patches.Wedge at 0x79d8a2c157e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c15c60>,
#   <matplotlib.patches.Wedge at 0x79d8a2c160e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c16560>,
#   <matplotlib.patches.Wedge at 0x79d8a2c169e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c16e60>,
#   <matplotlib.patches.Wedge at 0x79d8a2c172e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c17760>,
#   <matplotlib.patches.Wedge at 0x79d8a2c17be0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c500a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c50520>,
#   <matplotlib.patches.Wedge at 0x79d8a2c509a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c50e20>,
#   <matplotlib.patches.Wedge at 0x79d8a2c512a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c51720>,
#   <matplotlib.patches.Wedge at 0x79d8a2c51ba0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c52020>,
#   <matplotlib.patches.Wedge at 0x79d8a2c524a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c52920>,
#   <matplotlib.patches.Wedge at 0x79d8a2c52da0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c53220>,
#   <matplotlib.patches.Wedge at 0x79d8a2c536a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c53b20>,
#   <matplotlib.patches.Wedge at 0x79d8a2c53fa0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c84460>,
#   <matplotlib.patches.Wedge at 0x79d8a2c848e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c84d60>,
#   <matplotlib.patches.Wedge at 0x79d8a2c851e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c85660>,
#   <matplotlib.patches.Wedge at 0x79d8a2c85ae0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c85f60>,
#   <matplotlib.patches.Wedge at 0x79d8a2c863e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c86860>,
#   <matplotlib.patches.Wedge at 0x79d8a2c86ce0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c87160>,
#   <matplotlib.patches.Wedge at 0x79d8a2c875e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2c87a60>,
#   <matplotlib.patches.Wedge at 0x79d8a2c87ee0>,
#   <matplotlib.patches.Wedge at 0x79d8a2cc43a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2cc4820>,
#   <matplotlib.patches.Wedge at 0x79d8a2cc4ca0>,
#   <matplotlib.patches.Wedge at 0x79d8a2cc5120>,
#   <matplotlib.patches.Wedge at 0x79d8a2cc55a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2cc5a20>,
#   <matplotlib.patches.Wedge at 0x79d8a2cc5ea0>,
#   <matplotlib.patches.Wedge at 0x79d8a2cc6320>,
#   <matplotlib.patches.Wedge at 0x79d8a2cc67a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2cc6c20>,
#   <matplotlib.patches.Wedge at 0x79d8a2cc70a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2cc7520>,
#   <matplotlib.patches.Wedge at 0x79d8a2cc79a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2cc7e20>,
#   <matplotlib.patches.Wedge at 0x79d8a2b082e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b08760>,
#   <matplotlib.patches.Wedge at 0x79d8a2b08be0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b09060>,
#   <matplotlib.patches.Wedge at 0x79d8a2b094e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b09960>,
#   <matplotlib.patches.Wedge at 0x79d8a2b09de0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b0a260>,
#   <matplotlib.patches.Wedge at 0x79d8a2b0a6e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b0ab60>,
#   <matplotlib.patches.Wedge at 0x79d8a2b0afe0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b0b460>,
#   <matplotlib.patches.Wedge at 0x79d8a2b0b8e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b0bd60>,
#   <matplotlib.patches.Wedge at 0x79d8a2b44220>,
#   <matplotlib.patches.Wedge at 0x79d8a2b446a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b44b20>,
#   <matplotlib.patches.Wedge at 0x79d8a2b44fa0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b45420>,
#   <matplotlib.patches.Wedge at 0x79d8a2b458a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b45d20>,
#   <matplotlib.patches.Wedge at 0x79d8a2b461a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b46620>,
#   <matplotlib.patches.Wedge at 0x79d8a2b46aa0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b46f20>,
#   <matplotlib.patches.Wedge at 0x79d8a2b473a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b47820>,
#   <matplotlib.patches.Wedge at 0x79d8a2b47ca0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b74160>,
#   <matplotlib.patches.Wedge at 0x79d8a2b745e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b74a60>,
#   <matplotlib.patches.Wedge at 0x79d8a2b74ee0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b75360>,
#   <matplotlib.patches.Wedge at 0x79d8a2b757e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b75c60>,
#   <matplotlib.patches.Wedge at 0x79d8a2b760e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b76560>,
#   <matplotlib.patches.Wedge at 0x79d8a2b769e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b76e60>,
#   <matplotlib.patches.Wedge at 0x79d8a2b772e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2b77760>,
#   <matplotlib.patches.Wedge at 0x79d8a2b77be0>,
#   <matplotlib.patches.Wedge at 0x79d8a2bb00a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2bb0520>,
#   <matplotlib.patches.Wedge at 0x79d8a2bb09a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2bb0e20>,
#   <matplotlib.patches.Wedge at 0x79d8a2bb12a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2bb1720>,
#   <matplotlib.patches.Wedge at 0x79d8a2bb1ba0>,
#   <matplotlib.patches.Wedge at 0x79d8a2bb2020>,
#   <matplotlib.patches.Wedge at 0x79d8a2bb24a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2bb2920>,
#   <matplotlib.patches.Wedge at 0x79d8a2bb2da0>,
#   <matplotlib.patches.Wedge at 0x79d8a2bb3220>,
#   <matplotlib.patches.Wedge at 0x79d8a2bb36a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2bb3b20>,
#   <matplotlib.patches.Wedge at 0x79d8a2bb3fa0>,
#   <matplotlib.patches.Wedge at 0x79d8a2bf0460>,
#   <matplotlib.patches.Wedge at 0x79d8a2bf08e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2bf0d60>,
#   <matplotlib.patches.Wedge at 0x79d8a2bf11e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2bf1660>,
#   <matplotlib.patches.Wedge at 0x79d8a2bf1ae0>,
#   <matplotlib.patches.Wedge at 0x79d8a2bf1f60>,
#   <matplotlib.patches.Wedge at 0x79d8a2bf23e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2bf2860>,
#   <matplotlib.patches.Wedge at 0x79d8a2bf2ce0>,
#   <matplotlib.patches.Wedge at 0x79d8a2bf3160>,
#   <matplotlib.patches.Wedge at 0x79d8a2bf35e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2bf3a60>,
#   <matplotlib.patches.Wedge at 0x79d8a2bf3ee0>,
#   <matplotlib.patches.Wedge at 0x79d8a2a303a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2a30820>,
#   <matplotlib.patches.Wedge at 0x79d8a2a30ca0>,
#   <matplotlib.patches.Wedge at 0x79d8a2a31120>,
#   <matplotlib.patches.Wedge at 0x79d8a2a315a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2a31a20>,
#   <matplotlib.patches.Wedge at 0x79d8a2a31ea0>,
#   <matplotlib.patches.Wedge at 0x79d8a2a32320>,
#   <matplotlib.patches.Wedge at 0x79d8a2a327a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2a32c20>,
#   <matplotlib.patches.Wedge at 0x79d8a2a330a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2a33520>,
#   <matplotlib.patches.Wedge at 0x79d8a2a339a0>,
#   <matplotlib.patches.Wedge at 0x79d8a2a33e20>,
#   <matplotlib.patches.Wedge at 0x79d8a2a682e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2a68760>,
#   <matplotlib.patches.Wedge at 0x79d8a2a68be0>,
#   <matplotlib.patches.Wedge at 0x79d8a2a69060>,
#   <matplotlib.patches.Wedge at 0x79d8a2a694e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2a69960>,
#   <matplotlib.patches.Wedge at 0x79d8a2a69de0>,
#   <matplotlib.patches.Wedge at 0x79d8a2a6a260>,
#   <matplotlib.patches.Wedge at 0x79d8a2a6a6e0>,
#   <matplotlib.patches.Wedge at 0x79d8a2a6ab60>,
#   <matplotlib.patches.Wedge at 0x79d8a2a6b0d0>,
#   <matplotlib.patches.Wedge at 0x79d8a2a6b490>,
#   <matplotlib.patches.Wedge at 0x79d8a2a6b910>,
#   <matplotlib.patches.Wedge at 0x79d8a2a6bd90>,
#   <matplotlib.patches.Wedge at 0x79d8a2aa4250>,
#   <matplotlib.patches.Wedge at 0x79d8a2aa46d0>,
#   <matplotlib.patches.Wedge at 0x79d8a2aa4b50>,
#   <matplotlib.patches.Wedge at 0x79d8a2aa4fd0>,
#   <matplotlib.patches.Wedge at 0x79d8a2aa5450>,
#   <matplotlib.patches.Wedge at 0x79d8a2aa58d0>,
#   <matplotlib.patches.Wedge at 0x79d8a2aa5d50>,
#   <matplotlib.patches.Wedge at 0x79d8a2aa61d0>,
#   <matplotlib.patches.Wedge at 0x79d8a2aa6650>,
#   <matplotlib.patches.Wedge at 0x79d8a2aa6ad0>,
#   <matplotlib.patches.Wedge at 0x79d8a2aa6f50>,
#   <matplotlib.patches.Wedge at 0x79d8a2aa73d0>,
#   <matplotlib.patches.Wedge at 0x79d8a2aa7850>,
#   <matplotlib.patches.Wedge at 0x79d8a2aa7cd0>,
#   <matplotlib.patches.Wedge at 0x79d8a2ad8190>,
#   <matplotlib.patches.Wedge at 0x79d8a2ad8610>,
#   <matplotlib.patches.Wedge at 0x79d8a2ad8a90>,
#   <matplotlib.patches.Wedge at 0x79d8a2ad8f10>,
#   <matplotlib.patches.Wedge at 0x79d8a2ad9390>,
#   <matplotlib.patches.Wedge at 0x79d8a2ad9810>,
#   <matplotlib.patches.Wedge at 0x79d8a2ad9c90>,
#   <matplotlib.patches.Wedge at 0x79d8a2ada110>,
#   <matplotlib.patches.Wedge at 0x79d8a2ada590>,
#   <matplotlib.patches.Wedge at 0x79d8a2adaa10>,
#   <matplotlib.patches.Wedge at 0x79d8a2adae90>,
#   <matplotlib.patches.Wedge at 0x79d8a2adb310>,
#   <matplotlib.patches.Wedge at 0x79d8a2adb790>,
#   <matplotlib.patches.Wedge at 0x79d8a2adbc10>,
#   <matplotlib.patches.Wedge at 0x79d8a291c0d0>,
#   <matplotlib.patches.Wedge at 0x79d8a291c550>,
#   <matplotlib.patches.Wedge at 0x79d8a291c9d0>,
#   <matplotlib.patches.Wedge at 0x79d8a291ce50>,
#   <matplotlib.patches.Wedge at 0x79d8a291d2d0>,
#   <matplotlib.patches.Wedge at 0x79d8a291d750>,
#   <matplotlib.patches.Wedge at 0x79d8a291dbd0>,
#   <matplotlib.patches.Wedge at 0x79d8a291e050>,
#   <matplotlib.patches.Wedge at 0x79d8a291e4d0>,
#   <matplotlib.patches.Wedge at 0x79d8a291e950>,
#   <matplotlib.patches.Wedge at 0x79d8a291edd0>,
#   <matplotlib.patches.Wedge at 0x79d8a291f250>,
#   <matplotlib.patches.Wedge at 0x79d8a291f6d0>,
#   <matplotlib.patches.Wedge at 0x79d8a291fb50>,
#   <matplotlib.patches.Wedge at 0x79d8a291ffd0>,
#   <matplotlib.patches.Wedge at 0x79d8a2954490>,
#   <matplotlib.patches.Wedge at 0x79d8a2954910>,
#   <matplotlib.patches.Wedge at 0x79d8a2954d90>,
#   <matplotlib.patches.Wedge at 0x79d8a2955210>,
#   <matplotlib.patches.Wedge at 0x79d8a2955690>,
#   <matplotlib.patches.Wedge at 0x79d8a2955b10>,
#   <matplotlib.patches.Wedge at 0x79d8a2955f90>,
#   <matplotlib.patches.Wedge at 0x79d8a2956440>,
#   <matplotlib.patches.Wedge at 0x79d8a29568c0>,
#   <matplotlib.patches.Wedge at 0x79d8a2956d40>,
#   <matplotlib.patches.Wedge at 0x79d8a29571c0>,
#   <matplotlib.patches.Wedge at 0x79d8a2957640>,
#   <matplotlib.patches.Wedge at 0x79d8a2957ac0>,
#   <matplotlib.patches.Wedge at 0x79d8a2957f40>,
#   <matplotlib.patches.Wedge at 0x79d8a298c400>,
#   <matplotlib.patches.Wedge at 0x79d8a298c880>,
#   <matplotlib.patches.Wedge at 0x79d8a298cd00>,
#   <matplotlib.patches.Wedge at 0x79d8a298d180>,
#   <matplotlib.patches.Wedge at 0x79d8a298d600>,
#   <matplotlib.patches.Wedge at 0x79d8a298da80>,
#   <matplotlib.patches.Wedge at 0x79d8a298df00>,
#   <matplotlib.patches.Wedge at 0x79d8a298e380>,
#   <matplotlib.patches.Wedge at 0x79d8a298e800>,
#   <matplotlib.patches.Wedge at 0x79d8a298ec80>,
#   <matplotlib.patches.Wedge at 0x79d8a298f100>,
#   <matplotlib.patches.Wedge at 0x79d8a298f580>,
#   <matplotlib.patches.Wedge at 0x79d8a298fa00>,
#   <matplotlib.patches.Wedge at 0x79d8a298fe80>,
#   <matplotlib.patches.Wedge at 0x79d8a29cc340>,
#   <matplotlib.patches.Wedge at 0x79d8a29cc7c0>,
#   <matplotlib.patches.Wedge at 0x79d8a29ccc40>,
#   <matplotlib.patches.Wedge at 0x79d8a29cd0c0>,
#   <matplotlib.patches.Wedge at 0x79d8a29cd540>,
#   <matplotlib.patches.Wedge at 0x79d8a29cd9c0>,
#   <matplotlib.patches.Wedge at 0x79d8a29cde40>,
#   <matplotlib.patches.Wedge at 0x79d8a29ce2c0>,
#   <matplotlib.patches.Wedge at 0x79d8a29ce740>,
#   <matplotlib.patches.Wedge at 0x79d8a29cebc0>,
#   <matplotlib.patches.Wedge at 0x79d8a29cf040>,
#   <matplotlib.patches.Wedge at 0x79d8a29cf4c0>,
#   <matplotlib.patches.Wedge at 0x79d8a29cf940>,
#   <matplotlib.patches.Wedge at 0x79d8a29cfdc0>,
#   <matplotlib.patches.Wedge at 0x79d8a280c280>,
#   <matplotlib.patches.Wedge at 0x79d8a280c700>,
#   <matplotlib.patches.Wedge at 0x79d8a280cb80>,
#   <matplotlib.patches.Wedge at 0x79d8a280d000>,
#   <matplotlib.patches.Wedge at 0x79d8a280d480>,
#   <matplotlib.patches.Wedge at 0x79d8a280d900>,
#   <matplotlib.patches.Wedge at 0x79d8a280de70>,
#   <matplotlib.patches.Wedge at 0x79d8a280e230>,
#   <matplotlib.patches.Wedge at 0x79d8a280e6b0>,
#   <matplotlib.patches.Wedge at 0x79d8a280eb30>,
#   <matplotlib.patches.Wedge at 0x79d8a280efb0>,
#   <matplotlib.patches.Wedge at 0x79d8a280f430>,
#   <matplotlib.patches.Wedge at 0x79d8a280f8b0>,
#   <matplotlib.patches.Wedge at 0x79d8a280fd30>,
#   <matplotlib.patches.Wedge at 0x79d8a28481f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2848670>,
#   <matplotlib.patches.Wedge at 0x79d8a2848af0>,
#   <matplotlib.patches.Wedge at 0x79d8a2848f70>,
#   <matplotlib.patches.Wedge at 0x79d8a28493f0>,
#   <matplotlib.patches.Wedge at 0x79d8a2849870>,
#   <matplotlib.patches.Wedge at 0x79d8a2849cf0>,
#   <matplotlib.patches.Wedge at 0x79d8a284a170>,
#   <matplotlib.patches.Wedge at 0x79d8a284a5f0>,
#   <matplotlib.patches.Wedge at 0x79d8a284aa70>,
#   <matplotlib.patches.Wedge at 0x79d8a284aef0>,
#   <matplotlib.patches.Wedge at 0x79d8a284b370>,
#   <matplotlib.patches.Wedge at 0x79d8a284b7f0>,
#   <matplotlib.patches.Wedge at 0x79d8a284bc70>,
#   <matplotlib.patches.Wedge at 0x79d8a287c130>,
#   <matplotlib.patches.Wedge at 0x79d8a287c5b0>,
#   <matplotlib.patches.Wedge at 0x79d8a287ca30>,
#   <matplotlib.patches.Wedge at 0x79d8a287ceb0>,
#   <matplotlib.patches.Wedge at 0x79d8a287d330>,
#   <matplotlib.patches.Wedge at 0x79d8a287d9f0>,
#   <matplotlib.patches.Wedge at 0x79d8a287de40>,
#   <matplotlib.patches.Wedge at 0x79d8a287e2c0>,
#   <matplotlib.patches.Wedge at 0x79d8a287e740>,
#   <matplotlib.patches.Wedge at 0x79d8a287ebc0>,
#   <matplotlib.patches.Wedge at 0x79d8a287f040>,
#   <matplotlib.patches.Wedge at 0x79d8a287f2b0>,
#   <matplotlib.patches.Wedge at 0x79d8a287f6d0>,
#   <matplotlib.patches.Wedge at 0x79d8a287fb80>,
# ...
#   Text(1.068460626550517, 0.26151843053841745, ''),
#   Text(1.06837090734392, 0.26188471574555294, ''),
#   Text(1.0682811033769009, 0.2622508039412485, ''),
#   Text(1.0681912148369048, 0.2626166951000213, ''),
#   Text(1.0681012146231237, 0.2629825000272984, ''),
#   Text(1.0680111437787225, 0.26334805251693966, ''),
#   Text(1.0679210162223007, 0.26371329718224096, ''),
#   Text(1.0678307911532723, 0.2640784002242079, ''),
#   Text(1.0677404549774299, 0.2644434170188237, ''),
#   Text(1.0676501726036578, 0.2648076829311791, ''),
#   Text(1.0675599585325108, 0.2651711427325072, ''),
#   Text(1.0674696482788402, 0.26553446104686584, ''),
#   Text(1.067379228175405, 0.26589769321992396, ''),
#   Text(1.0672886844735072, 0.2662608946030385, ''),
#   Text(1.0671980171836315, 0.26662406515415227, ''),
#   Text(1.0671072540139144, 0.266987094127944, ''),
#   Text(1.0670164089539529, 0.2673499261698252, ''),
#   Text(1.066925454410729, 0.2677126719646638, ''),
#   Text(1.0668343904573248, 0.2680753314602982, ''),
#   Text(1.0667432310832503, 0.26843784930234277, ''),
#   Text(1.0666519624643958, 0.2688002808236133, ''),
#   Text(1.0665605707075643, 0.26916268131365334, ''),
#   Text(1.0664690558233059, 0.26952505073062616, ''),
#   Text(1.0663774318198986, 0.26988733372501483, ''),
#   Text(1.0662857127869585, 0.2702494749419651, ''),
#   Text(1.066193898844691, 0.2706114743804422, ''),
#   Text(1.0661019760561103, 0.2709733873450614, ''),
#   Text(1.0660099726492196, 0.2713351031702505, ''),
#   Text(1.0659178888035035, 0.27169662185732485, ''),
#   Text(1.0658256823550347, 0.2720581092936302, ''),
#   Text(1.065733367443463, 0.2724195101633085, ''),
#   Text(1.0656409441356351, 0.2727808244391676, ''),
#   Text(1.0655483983318759, 0.27314210735874156, ''),
#   Text(1.0654557442312036, 0.2735033036084432, ''),
#   Text(1.0653629819004788, 0.2738644131611851, ''),
